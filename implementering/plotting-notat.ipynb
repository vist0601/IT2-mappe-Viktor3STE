# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return 3*x**2

# %%
x = []
y = []
for i in range (20):
    x.append(i)
    y.append(f(i))

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 200, 10)
y = f(x)
y
# Out:
# array([     0.        ,   1481.48148148,   5925.92592593,  13333.33333333,
#         23703.7037037 ,  37037.03703704,  53333.33333333,  72592.59259259,
#         94814.81481481, 120000.        ])

# %%
plt.plot(x, y)
plt.title("$3x^2$")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %%
plt.style.available
